# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy import stats
from scipy.stats import linregress


# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 604

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
url = "https://api.openweathermap.org/data/2.5/weather?appid=" + weather_api_key + "&q=" + "Tempe"

# # Run request
response = requests.get(url)
resp_data = response.json()

# Print the json (pretty printed)
print(json.dumps(resp_data, indent=4, sort_keys=False))
# Out:
# {
#     "coord": {
#         "lon": -111.9093,
#         "lat": 33.4148
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 290.43,
#         "feels_like": 289.08,
#         "temp_min": 285.88,
#         "temp_max": 294.36,
#         "pressure": 1014,
#         "humidity": 33
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.63,
#         "deg": 100
#     },
#     "clouds": {
#         "all": 20
#     },
#     "dt": 1680104417,
#     "sys": {
#         "type": 2,
#         "id": 2021149,
#         "country": "US",
#         "sunrise": 1680095963,
#         "sunset": 1680140713
#     },
#     "timezone": -25200,
#     "id": 5317058,
#     "name": "Tempe",
#     "cod": 200
# }

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather_json = requests.get(city_url)
        city_weather = city_weather_json.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | cidreira
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | soma
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | bon air
# Processing Record 7 of Set 1 | noumea
# Processing Record 8 of Set 1 | logansport
# Processing Record 9 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 10 of Set 1 | lismore
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | shangqiu
# Processing Record 14 of Set 1 | imeni poliny osipenko
# Processing Record 15 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 1 | caravelas
# Processing Record 17 of Set 1 | nikolskoye
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | severo-kurilsk
# Processing Record 20 of Set 1 | college
# Processing Record 21 of Set 1 | cabo san lucas
# Processing Record 22 of Set 1 | basco
# Processing Record 23 of Set 1 | gorontalo
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | geraldton
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | kulykiv
# Processing Record 28 of Set 1 | sur
# Processing Record 29 of Set 1 | kloulklubed
# Processing Record 30 of Set 1 | naze
# Processing Record 31 of Set 1 | pokaran
# Processing Record 32 of Set 1 | longyearbyen
# Processing Record 33 of Set 1 | komsomolskiy
# Processing Record 34 of Set 1 | paamiut
# Processing Record 35 of Set 1 | tuktoyaktuk
# Processing Record 36 of Set 1 | malanville
# Processing Record 37 of Set 1 | bethel
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | mount gambier
# Processing Record 40 of Set 1 | provideniya
# Processing Record 41 of Set 1 | pisco
# Processing Record 42 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 1 | chuy
# Processing Record 44 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 1 | avarua
# Processing Record 46 of Set 1 | adrar
# Processing Record 47 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 1 | quelimane
# Processing Record 49 of Set 1 | doka
# Processing Record 50 of Set 1 | lebu
# Processing Record 0 of Set 2 | nara
# Processing Record 1 of Set 2 | lata
# Processing Record 2 of Set 2 | ushuaia
# Processing Record 3 of Set 2 | mantua
# Processing Record 4 of Set 2 | souillac
# Processing Record 5 of Set 2 | ndioum
# Processing Record 6 of Set 2 | kontagora
# Processing Record 7 of Set 2 | vaini
# Processing Record 8 of Set 2 | atuona
# Processing Record 9 of Set 2 | kavaratti
# Processing Record 10 of Set 2 | nuuk
# Processing Record 11 of Set 2 | lavrentiya
# Processing Record 12 of Set 2 | mahebourg
# Processing Record 13 of Set 2 | watsa
# Processing Record 14 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 2 | dingle
# Processing Record 16 of Set 2 | castro
# Processing Record 17 of Set 2 | sao joao da barra
# Processing Record 18 of Set 2 | mar del plata
# Processing Record 19 of Set 2 | amparafaravola
# Processing Record 20 of Set 2 | constitucion
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | dhangadhi
# Processing Record 23 of Set 2 | torbay
# Processing Record 24 of Set 2 | acajutla
# Processing Record 25 of Set 2 | punta arenas
# Processing Record 26 of Set 2 | norman wells
# Processing Record 27 of Set 2 | port alfred
# Processing Record 28 of Set 2 | tandalti
# Processing Record 29 of Set 2 | busselton
# Processing Record 30 of Set 2 | sudak
# Processing Record 31 of Set 2 | suez
# Processing Record 32 of Set 2 | pevek
# Processing Record 33 of Set 2 | saint george
# Processing Record 34 of Set 2 | selfoss
# Processing Record 35 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 2 | acapulco
# Processing Record 37 of Set 2 | cape town
# Processing Record 38 of Set 2 | seoul
# Processing Record 39 of Set 2 | san jeronimo
# Processing Record 40 of Set 2 | east london
# Processing Record 41 of Set 2 | georgetown
# Processing Record 42 of Set 2 | ahumada
# City not found. Skipping...
# Processing Record 43 of Set 2 | hermanus
# Processing Record 44 of Set 2 | nalut
# Processing Record 45 of Set 2 | corrente
# Processing Record 46 of Set 2 | carnarvon
# Processing Record 47 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 2 | kruisfontein
# Processing Record 49 of Set 2 | morant bay
# Processing Record 0 of Set 3 | waiouru
# Processing Record 1 of Set 3 | codrington
# Processing Record 2 of Set 3 | havoysund
# Processing Record 3 of Set 3 | puerto berrio
# Processing Record 4 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 3 | airai
# Processing Record 6 of Set 3 | moose factory
# Processing Record 7 of Set 3 | saint-philippe
# Processing Record 8 of Set 3 | sterling
# Processing Record 9 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 3 | khatanga
# Processing Record 11 of Set 3 | grindavik
# Processing Record 12 of Set 3 | hithadhoo
# Processing Record 13 of Set 3 | kodiak
# Processing Record 14 of Set 3 | moyobamba
# Processing Record 15 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 3 | iqaluit
# Processing Record 17 of Set 3 | adiake
# Processing Record 18 of Set 3 | linden
# Processing Record 19 of Set 3 | saldanha
# Processing Record 20 of Set 3 | vao
# Processing Record 21 of Set 3 | tasiilaq
# Processing Record 22 of Set 3 | gazanjyk
# Processing Record 23 of Set 3 | puerto ayora
# Processing Record 24 of Set 3 | lasa
# Processing Record 25 of Set 3 | byron bay
# Processing Record 26 of Set 3 | matara
# Processing Record 27 of Set 3 | bambous virieux
# Processing Record 28 of Set 3 | barrow
# Processing Record 29 of Set 3 | almaznyy
# Processing Record 30 of Set 3 | carballo
# Processing Record 31 of Set 3 | madras
# Processing Record 32 of Set 3 | ostrovnoy
# Processing Record 33 of Set 3 | kimbe
# Processing Record 34 of Set 3 | talnakh
# Processing Record 35 of Set 3 | faanui
# Processing Record 36 of Set 3 | kyzyl-suu
# Processing Record 37 of Set 3 | ambilobe
# Processing Record 38 of Set 3 | key west
# Processing Record 39 of Set 3 | klaksvik
# Processing Record 40 of Set 3 | puerto carreno
# Processing Record 41 of Set 3 | port elizabeth
# Processing Record 42 of Set 3 | saint anthony
# Processing Record 43 of Set 3 | abu kamal
# Processing Record 44 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 3 | lagoa
# Processing Record 46 of Set 3 | chokurdakh
# Processing Record 47 of Set 3 | hamilton
# Processing Record 48 of Set 3 | vila velha
# Processing Record 49 of Set 3 | pacific grove
# Processing Record 0 of Set 4 | wanning
# Processing Record 1 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 4 | ilulissat
# Processing Record 3 of Set 4 | keflavik
# Processing Record 4 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 4 | les trois-bassins
# Processing Record 6 of Set 4 | sidi ali
# Processing Record 7 of Set 4 | red deer
# Processing Record 8 of Set 4 | katsuura
# Processing Record 9 of Set 4 | upernavik
# Processing Record 10 of Set 4 | cairns
# Processing Record 11 of Set 4 | toowoomba
# Processing Record 12 of Set 4 | kahului
# Processing Record 13 of Set 4 | qaanaaq
# Processing Record 14 of Set 4 | jiayuguan
# Processing Record 15 of Set 4 | anadyr
# Processing Record 16 of Set 4 | lompoc
# Processing Record 17 of Set 4 | sitka
# Processing Record 18 of Set 4 | novoilinsk
# Processing Record 19 of Set 4 | havre-saint-pierre
# Processing Record 20 of Set 4 | razole
# Processing Record 21 of Set 4 | touros
# Processing Record 22 of Set 4 | port hardy
# Processing Record 23 of Set 4 | oranjemund
# Processing Record 24 of Set 4 | lekoni
# Processing Record 25 of Set 4 | clyde river
# Processing Record 26 of Set 4 | brae
# Processing Record 27 of Set 4 | hasaki
# Processing Record 28 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 29 of Set 4 | sovetskiy
# Processing Record 30 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 4 | listvyanskiy
# Processing Record 32 of Set 4 | cherskiy
# Processing Record 33 of Set 4 | guerrero negro
# Processing Record 34 of Set 4 | maldonado
# Processing Record 35 of Set 4 | makat
# Processing Record 36 of Set 4 | kirando
# Processing Record 37 of Set 4 | te anau
# Processing Record 38 of Set 4 | coihaique
# Processing Record 39 of Set 4 | chkalovsk
# Processing Record 40 of Set 4 | quatre cocos
# Processing Record 41 of Set 4 | chara
# Processing Record 42 of Set 4 | aldan
# Processing Record 43 of Set 4 | grand gaube
# Processing Record 44 of Set 4 | mahanje
# Processing Record 45 of Set 4 | alofi
# Processing Record 46 of Set 4 | grimshaw
# Processing Record 47 of Set 4 | la asuncion
# Processing Record 48 of Set 4 | araouane
# Processing Record 49 of Set 4 | victoria
# Processing Record 0 of Set 5 | broome
# Processing Record 1 of Set 5 | omsukchan
# Processing Record 2 of Set 5 | nyurba
# Processing Record 3 of Set 5 | tagusao
# Processing Record 4 of Set 5 | santa cruz cabralia
# Processing Record 5 of Set 5 | cherrapunji
# Processing Record 6 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 5 | broken hill
# Processing Record 8 of Set 5 | bonavista
# Processing Record 9 of Set 5 | dunedin
# Processing Record 10 of Set 5 | taiyuan
# Processing Record 11 of Set 5 | san policarpo
# Processing Record 12 of Set 5 | mokhotlong
# Processing Record 13 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 5 | isangel
# Processing Record 15 of Set 5 | bredasdorp
# Processing Record 16 of Set 5 | nanortalik
# Processing Record 17 of Set 5 | moindou
# Processing Record 18 of Set 5 | bathsheba
# Processing Record 19 of Set 5 | el sauzal
# Processing Record 20 of Set 5 | walvis bay
# Processing Record 21 of Set 5 | batagay
# Processing Record 22 of Set 5 | bafra
# Processing Record 23 of Set 5 | luganville
# Processing Record 24 of Set 5 | linqing
# Processing Record 25 of Set 5 | leningradskiy
# Processing Record 26 of Set 5 | somerset east
# Processing Record 27 of Set 5 | fontanafredda
# Processing Record 28 of Set 5 | ribeira grande
# Processing Record 29 of Set 5 | whitehorse
# Processing Record 30 of Set 5 | ugoofaaru
# Processing Record 31 of Set 5 | kaitangata
# Processing Record 32 of Set 5 | krasnoselkup
# Processing Record 33 of Set 5 | nynashamn
# Processing Record 34 of Set 5 | batagay-alyta
# Processing Record 35 of Set 5 | anloga
# Processing Record 36 of Set 5 | narsaq
# Processing Record 37 of Set 5 | miri
# Processing Record 38 of Set 5 | lichtenburg
# Processing Record 39 of Set 5 | xuddur
# Processing Record 40 of Set 5 | beyneu
# Processing Record 41 of Set 5 | skibbereen
# Processing Record 42 of Set 5 | pringsewu
# Processing Record 43 of Set 5 | tual
# Processing Record 44 of Set 5 | tazovskiy
# Processing Record 45 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 5 | taltal
# Processing Record 47 of Set 5 | hay river
# Processing Record 48 of Set 5 | kungurtug
# Processing Record 49 of Set 5 | kapaa
# Processing Record 0 of Set 6 | vila franca do campo
# Processing Record 1 of Set 6 | kalengwa
# Processing Record 2 of Set 6 | comodoro rivadavia
# Processing Record 3 of Set 6 | chernyshevskiy
# Processing Record 4 of Set 6 | yining
# Processing Record 5 of Set 6 | petrokamenskoye
# Processing Record 6 of Set 6 | santo antonio do sudoeste
# Processing Record 7 of Set 6 | nhulunbuy
# Processing Record 8 of Set 6 | malanje
# Processing Record 9 of Set 6 | caiaponia
# Processing Record 10 of Set 6 | cap malheureux
# Processing Record 11 of Set 6 | maloshuyka
# City not found. Skipping...
# Processing Record 12 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 6 | makoshyne
# Processing Record 14 of Set 6 | whitianga
# Processing Record 15 of Set 6 | heihe
# Processing Record 16 of Set 6 | qasigiannguit
# Processing Record 17 of Set 6 | mayo
# Processing Record 18 of Set 6 | thompson
# Processing Record 19 of Set 6 | shaunavon
# Processing Record 20 of Set 6 | manokwari
# Processing Record 21 of Set 6 | malindi
# Processing Record 22 of Set 6 | fuzhou
# Processing Record 23 of Set 6 | kyra
# Processing Record 24 of Set 6 | esmeraldas
# Processing Record 25 of Set 6 | ponta do sol
# Processing Record 26 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 27 of Set 6 | berdigestyakh
# Processing Record 28 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 6 | mahina
# Processing Record 30 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 6 | sainte-suzanne
# Processing Record 32 of Set 6 | sumbe
# Processing Record 33 of Set 6 | statesboro
# Processing Record 34 of Set 6 | labuan
# Processing Record 35 of Set 6 | dikson
# Processing Record 36 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 37 of Set 6 | half moon bay
# Processing Record 38 of Set 6 | diffa
# Processing Record 39 of Set 6 | marawi
# Processing Record 40 of Set 6 | christiana
# Processing Record 41 of Set 6 | luyang
# Processing Record 42 of Set 6 | honiara
# Processing Record 43 of Set 6 | pathalgaon
# Processing Record 44 of Set 6 | esperance
# Processing Record 45 of Set 6 | glasgow
# Processing Record 46 of Set 6 | tigil
# Processing Record 47 of Set 6 | adre
# Processing Record 48 of Set 6 | nantucket
# Processing Record 49 of Set 6 | debe
# Processing Record 0 of Set 7 | conde
# Processing Record 1 of Set 7 | maracacume
# Processing Record 2 of Set 7 | ancud
# Processing Record 3 of Set 7 | zhigansk
# Processing Record 4 of Set 7 | ekibastuz
# Processing Record 5 of Set 7 | dekar
# Processing Record 6 of Set 7 | sibolga
# Processing Record 7 of Set 7 | andrews
# Processing Record 8 of Set 7 | mareeba
# Processing Record 9 of Set 7 | gat
# Processing Record 10 of Set 7 | palu
# Processing Record 11 of Set 7 | asau
# Processing Record 12 of Set 7 | jamame
# Processing Record 13 of Set 7 | pestovo
# Processing Record 14 of Set 7 | jijiga
# Processing Record 15 of Set 7 | katima mulilo
# Processing Record 16 of Set 7 | kokoda
# Processing Record 17 of Set 7 | sokolo
# Processing Record 18 of Set 7 | tessalit
# Processing Record 19 of Set 7 | arraial do cabo
# Processing Record 20 of Set 7 | lorengau
# Processing Record 21 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 22 of Set 7 | shimoda
# Processing Record 23 of Set 7 | kaduy
# Processing Record 24 of Set 7 | yar-sale
# Processing Record 25 of Set 7 | bubaque
# Processing Record 26 of Set 7 | tuatapere
# Processing Record 27 of Set 7 | aksu
# Processing Record 28 of Set 7 | aklavik
# Processing Record 29 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 7 | itau de minas
# Processing Record 31 of Set 7 | kavieng
# Processing Record 32 of Set 7 | goba
# Processing Record 33 of Set 7 | rorvik
# Processing Record 34 of Set 7 | neiafu
# Processing Record 35 of Set 7 | manavalakurichi
# Processing Record 36 of Set 7 | pandamatenga
# Processing Record 37 of Set 7 | coos bay
# Processing Record 38 of Set 7 | mathbaria
# Processing Record 39 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 7 | san patricio
# Processing Record 41 of Set 7 | qianan
# Processing Record 42 of Set 7 | vysokogornyy
# Processing Record 43 of Set 7 | boende
# Processing Record 44 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 45 of Set 7 | coquimbo
# Processing Record 46 of Set 7 | syumsi
# Processing Record 47 of Set 7 | porto velho
# Processing Record 48 of Set 7 | chavakachcheri
# Processing Record 49 of Set 7 | port-cartier
# Processing Record 0 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 8 | sobolevo
# Processing Record 2 of Set 8 | port lincoln
# Processing Record 3 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 4 of Set 8 | luderitz
# Processing Record 5 of Set 8 | ito
# Processing Record 6 of Set 8 | notodden
# Processing Record 7 of Set 8 | kroya
# Processing Record 8 of Set 8 | igarka
# Processing Record 9 of Set 8 | flin flon
# Processing Record 10 of Set 8 | uttaradit
# Processing Record 11 of Set 8 | balikpapan
# Processing Record 12 of Set 8 | nokaneng
# Processing Record 13 of Set 8 | kashi
# Processing Record 14 of Set 8 | bama
# Processing Record 15 of Set 8 | makakilo city
# Processing Record 16 of Set 8 | ulladulla
# Processing Record 17 of Set 8 | dakar
# Processing Record 18 of Set 8 | itaituba
# Processing Record 19 of Set 8 | miles city
# Processing Record 20 of Set 8 | dunhua
# Processing Record 21 of Set 8 | assiniboia
# Processing Record 22 of Set 8 | kidal
# Processing Record 23 of Set 8 | point pedro
# Processing Record 24 of Set 8 | tura
# Processing Record 25 of Set 8 | north bend
# Processing Record 26 of Set 8 | acari
# Processing Record 27 of Set 8 | damghan
# Processing Record 28 of Set 8 | camocim
# Processing Record 29 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 31 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 8 | haukipudas
# Processing Record 33 of Set 8 | solvychegodsk
# Processing Record 34 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 8 | urusha
# Processing Record 36 of Set 8 | bukama
# Processing Record 37 of Set 8 | amapa
# Processing Record 38 of Set 8 | yulara
# Processing Record 39 of Set 8 | kinshasa
# Processing Record 40 of Set 8 | praya
# Processing Record 41 of Set 8 | bali
# Processing Record 42 of Set 8 | lagos
# Processing Record 43 of Set 8 | hunza
# City not found. Skipping...
# Processing Record 44 of Set 8 | shelburne
# Processing Record 45 of Set 8 | mumford
# Processing Record 46 of Set 8 | olinda
# Processing Record 47 of Set 8 | korla
# Processing Record 48 of Set 8 | sorong
# Processing Record 49 of Set 8 | dudinka
# Processing Record 0 of Set 9 | saskylakh
# Processing Record 1 of Set 9 | gushi
# Processing Record 2 of Set 9 | dalby
# Processing Record 3 of Set 9 | erdenet
# Processing Record 4 of Set 9 | burgeo
# Processing Record 5 of Set 9 | plettenberg bay
# Processing Record 6 of Set 9 | nome
# Processing Record 7 of Set 9 | muros
# Processing Record 8 of Set 9 | buchanan
# Processing Record 9 of Set 9 | grajau
# Processing Record 10 of Set 9 | mbengwi
# Processing Record 11 of Set 9 | ayorou
# Processing Record 12 of Set 9 | den helder
# Processing Record 13 of Set 9 | hofn
# Processing Record 14 of Set 9 | hammerfest
# Processing Record 15 of Set 9 | saint-francois
# Processing Record 16 of Set 9 | karratha
# Processing Record 17 of Set 9 | bagepalli
# Processing Record 18 of Set 9 | novoseleznevo
# Processing Record 19 of Set 9 | marzuq
# Processing Record 20 of Set 9 | lerdo
# Processing Record 21 of Set 9 | port hedland
# Processing Record 22 of Set 9 | portland
# Processing Record 23 of Set 9 | alcudia
# Processing Record 24 of Set 9 | northam
# Processing Record 25 of Set 9 | limon
# Processing Record 26 of Set 9 | banda aceh
# Processing Record 27 of Set 9 | ketchikan
# Processing Record 28 of Set 9 | mildura
# Processing Record 29 of Set 9 | guiratinga
# Processing Record 30 of Set 9 | benghazi
# Processing Record 31 of Set 9 | harper
# Processing Record 32 of Set 9 | nanfeng
# Processing Record 33 of Set 9 | opunake
# Processing Record 34 of Set 9 | beloha
# Processing Record 35 of Set 9 | hirara
# Processing Record 36 of Set 9 | perbaungan
# Processing Record 37 of Set 9 | walsrode
# Processing Record 38 of Set 9 | daru
# Processing Record 39 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 40 of Set 9 | barquisimeto
# Processing Record 41 of Set 9 | southbridge
# Processing Record 42 of Set 9 | shingu
# Processing Record 43 of Set 9 | visnes
# Processing Record 44 of Set 9 | fonte boa
# Processing Record 45 of Set 9 | aberdeen
# Processing Record 46 of Set 9 | gisborne
# Processing Record 47 of Set 9 | saint-pierre
# Processing Record 48 of Set 9 | solnechnyy
# Processing Record 49 of Set 9 | arlit
# Processing Record 0 of Set 10 | machaneng
# Processing Record 1 of Set 10 | kachug
# Processing Record 2 of Set 10 | verin
# Processing Record 3 of Set 10 | kieta
# Processing Record 4 of Set 10 | toguchin
# Processing Record 5 of Set 10 | buala
# Processing Record 6 of Set 10 | pangai
# Processing Record 7 of Set 10 | kindu
# Processing Record 8 of Set 10 | houma
# Processing Record 9 of Set 10 | matagami
# Processing Record 10 of Set 10 | omboue
# Processing Record 11 of Set 10 | acucena
# Processing Record 12 of Set 10 | ust-kuyga
# Processing Record 13 of Set 10 | los llanos de aridane
# Processing Record 14 of Set 10 | kabanjahe
# Processing Record 15 of Set 10 | tiksi
# Processing Record 16 of Set 10 | menongue
# Processing Record 17 of Set 10 | sorland
# Processing Record 18 of Set 10 | vilhena
# Processing Record 19 of Set 10 | elat
# Processing Record 20 of Set 10 | langsa
# Processing Record 21 of Set 10 | mancheral
# Processing Record 22 of Set 10 | guangyuan
# Processing Record 23 of Set 10 | jizan
# Processing Record 24 of Set 10 | cayenne
# Processing Record 25 of Set 10 | cabedelo
# Processing Record 26 of Set 10 | havelock
# Processing Record 27 of Set 10 | vastervik
# City not found. Skipping...
# Processing Record 28 of Set 10 | deputatskiy
# Processing Record 29 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 30 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 10 | poum
# Processing Record 32 of Set 10 | jalu
# Processing Record 33 of Set 10 | alyangula
# Processing Record 34 of Set 10 | vila
# Processing Record 35 of Set 10 | necochea
# Processing Record 36 of Set 10 | villa maria
# Processing Record 37 of Set 10 | grenaa
# Processing Record 38 of Set 10 | chazuta
# Processing Record 39 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 10 | springville
# Processing Record 41 of Set 10 | aripuana
# Processing Record 42 of Set 10 | pochutla
# Processing Record 43 of Set 10 | sainte-martine
# Processing Record 44 of Set 10 | port-gentil
# Processing Record 45 of Set 10 | point fortin
# Processing Record 46 of Set 10 | shelbyville
# Processing Record 47 of Set 10 | abu samrah
# Processing Record 48 of Set 10 | roald
# Processing Record 49 of Set 10 | hauterive
# Processing Record 0 of Set 11 | berlevag
# Processing Record 1 of Set 11 | toba
# Processing Record 2 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 3 of Set 11 | tabuk
# Processing Record 4 of Set 11 | killam
# Processing Record 5 of Set 11 | bambanglipuro
# Processing Record 6 of Set 11 | nazarovo
# Processing Record 7 of Set 11 | praia da vitoria
# Processing Record 8 of Set 11 | cumberland
# Processing Record 9 of Set 11 | avera
# Processing Record 10 of Set 11 | kampong thum
# Processing Record 11 of Set 11 | sao felix do xingu
# Processing Record 12 of Set 11 | clarence town
# Processing Record 13 of Set 11 | jonava
# Processing Record 14 of Set 11 | farim
# Processing Record 15 of Set 11 | fomboni
# Processing Record 16 of Set 11 | muriwai beach
# Processing Record 17 of Set 11 | phichit
# Processing Record 18 of Set 11 | faya
# Processing Record 19 of Set 11 | sinnamary
# Processing Record 20 of Set 11 | atar
# Processing Record 21 of Set 11 | chicama
# Processing Record 22 of Set 11 | bud
# Processing Record 23 of Set 11 | ust-dzheguta
# Processing Record 24 of Set 11 | cuamba
# Processing Record 25 of Set 11 | sarangani
# Processing Record 26 of Set 11 | dire
# Processing Record 27 of Set 11 | mercedes
# Processing Record 28 of Set 11 | udachnyy
# Processing Record 29 of Set 11 | moron
# Processing Record 30 of Set 11 | cedar city
# Processing Record 31 of Set 11 | moa
# Processing Record 32 of Set 11 | kodinsk
# Processing Record 33 of Set 11 | aykhal
# Processing Record 34 of Set 11 | linqiong
# Processing Record 35 of Set 11 | sechura
# Processing Record 36 of Set 11 | san rafael
# Processing Record 37 of Set 11 | mosquera
# Processing Record 38 of Set 11 | mount pleasant
# Processing Record 39 of Set 11 | amahai
# Processing Record 40 of Set 11 | ixtapa
# Processing Record 41 of Set 11 | ngunguru
# Processing Record 42 of Set 11 | talaya
# Processing Record 43 of Set 11 | abbeville
# Processing Record 44 of Set 11 | vestmannaeyjar
# Processing Record 45 of Set 11 | wazzan
# City not found. Skipping...
# Processing Record 46 of Set 11 | sao miguel do araguaia
# Processing Record 47 of Set 11 | minab
# Processing Record 48 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 49 of Set 11 | regina
# Processing Record 0 of Set 12 | lucapa
# Processing Record 1 of Set 12 | sjenica
# Processing Record 2 of Set 12 | japura
# Processing Record 3 of Set 12 | barra
# Processing Record 4 of Set 12 | maniitsoq
# Processing Record 5 of Set 12 | sindor
# Processing Record 6 of Set 12 | yongan
# Processing Record 7 of Set 12 | carlagan
# Processing Record 8 of Set 12 | mastic beach
# Processing Record 9 of Set 12 | verkhnevilyuysk
# Processing Record 10 of Set 12 | kununurra
# Processing Record 11 of Set 12 | cam ranh
# Processing Record 12 of Set 12 | diofior
# Processing Record 13 of Set 12 | shimanovsk
# Processing Record 14 of Set 12 | olavarria
# Processing Record 15 of Set 12 | bengkulu
# Processing Record 16 of Set 12 | tanabe
# Processing Record 17 of Set 12 | saurimo
# Processing Record 18 of Set 12 | vinnytsya
# Processing Record 19 of Set 12 | santa maria
# Processing Record 20 of Set 12 | kuusamo
# Processing Record 21 of Set 12 | san cristobal
# Processing Record 22 of Set 12 | gladstone
# Processing Record 23 of Set 12 | kudahuvadhoo
# Processing Record 24 of Set 12 | marystown
# Processing Record 25 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 26 of Set 12 | cururupu
# Processing Record 27 of Set 12 | yerbogachen
# Processing Record 28 of Set 12 | mandiana
# Processing Record 29 of Set 12 | mulege
# Processing Record 30 of Set 12 | teya
# Processing Record 31 of Set 12 | mulchen
# Processing Record 32 of Set 12 | buraydah
# Processing Record 33 of Set 12 | mpika
# Processing Record 34 of Set 12 | masaling
# Processing Record 35 of Set 12 | milledgeville
# Processing Record 36 of Set 12 | galle
# Processing Record 37 of Set 12 | maralal
# Processing Record 38 of Set 12 | srednekolymsk
# Processing Record 39 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 12 | sao filipe
# Processing Record 41 of Set 12 | chifeng
# Processing Record 42 of Set 12 | kizema
# Processing Record 43 of Set 12 | samarai
# Processing Record 44 of Set 12 | tautira
# Processing Record 45 of Set 12 | porto walter
# Processing Record 46 of Set 12 | itarare
# Processing Record 47 of Set 12 | ayan
# Processing Record 48 of Set 12 | solano
# Processing Record 49 of Set 12 | zasosna
# Processing Record 0 of Set 13 | rawson
# Processing Record 1 of Set 13 | farafangana
# Processing Record 2 of Set 13 | laguna
# Processing Record 3 of Set 13 | henties bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          558
# Lat           558
# Lng           558
# Max Temp      558
# Humidity      558
# Cloudiness    558
# Wind Speed    558
# Country       558
# Date          558
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  butaritari   3.0707  172.7902    300.04        84          81        6.03
# 1    cidreira -30.1811  -50.2056    301.63        62           0        1.89
# 2     rikitea -23.1203 -134.9692    299.42        74          97        2.18
# 3        soma  39.1855   27.6094    281.51        39          98        5.44
# 4      hobart -42.8794  147.3294    287.18        81         100        7.20
#
#   Country        Date
# 0      KI  1680103630
# 1      BR  1680103631
# 2      PF  1680103620
# 3      TR  1680103632
# 4      AU  1680103633

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        butaritari   3.0707  172.7902    300.04        84          81
# 1          cidreira -30.1811  -50.2056    301.63        62           0
# 2           rikitea -23.1203 -134.9692    299.42        74          97
# 3              soma  39.1855   27.6094    281.51        39          98
# 4            hobart -42.8794  147.3294    287.18        81         100
#
#          Wind Speed Country        Date
# City_ID
# 0              6.03      KI  1680103630
# 1              1.89      BR  1680103631
# 2              2.18      PF  1680103620
# 3              5.44      TR  1680103632
# 4              7.20      AU  1680103633

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# city_data_df.plot(kind='scatter', x='Lat', y='Max Temp')
# plt.show()

x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.show()

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# city_data_df.plot(kind='scatter', x='Lat', y='Humidity')
# plt.show()

x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# city_data_df.plot(kind='scatter', x='Lat', y='Cloudiness')
# plt.show()

x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# city_data_df.plot(kind='scatter', x='Lat', y='Wind Speed')

x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0), :]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        butaritari   3.0707  172.7902    300.04        84          81
# 3              soma  39.1855   27.6094    281.51        39          98
# 5           bon air  37.5249  -77.5578    285.98        55           0
# 7        logansport  40.7545  -86.3567    281.33        68           0
# 9              hilo  19.7297 -155.0900    296.64        89         100
#
#          Wind Speed Country        Date
# City_ID
# 0              6.03      KI  1680103630
# 3              5.44      TR  1680103632
# 5              2.57      US  1680103633
# 7              6.17      US  1680103635
# 9              3.09      US  1680103403

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0), :]
# Display sample data
southern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        cidreira -30.1811  -50.2056    301.63        62           0
# 2         rikitea -23.1203 -134.9692    299.42        74          97
# 4          hobart -42.8794  147.3294    287.18        81         100
# 6          noumea -22.2763  166.4572    295.14        87          97
# 8         lismore -28.8135  153.2773    293.54        95          74
#
#          Wind Speed Country        Date
# City_ID
# 1              1.89      BR  1680103631
# 2              2.18      PF  1680103620
# 4              7.20      AU  1680103633
# 6              4.00      NC  1680103634
# 8              1.88      AU  1680103635

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,5),fontsize=15,color="red")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_532\1219442154.py in <module>
#       6
#       7 plt.scatter(x_values,y_values)
# ----> 8 plt.plot(x_values,regress_values,"r-")
#       9
#      10 # Label plot and annotate the line equation
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     496
#     497         if x.shape[0] != y.shape[0]:
# --> 498             raise ValueError(f"x and y must have same first dimension, but "
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (364,) and (558,)

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,5),fontsize=15,color="red")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_532\1582791024.py in <module>
#       6
#       7 plt.scatter(x_values,y_values)
# ----> 8 plt.plot(x_values,regress_values,"r-")
#       9
#      10 # Label plot and annotate the line equation
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     496
#     497         if x.shape[0] != y.shape[0]:
# --> 498             raise ValueError(f"x and y must have same first dimension, but "
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (194,) and (558,)

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
